# %% [markdown]
# ## Simple Linear Regression
#     Focuses on 1 dependent variable and 1 indepedent variable
#
# ### Steps:
#     Read the dataset
#     Perform basic quality checks
#     Performing data cleaning - handling missing data, remove the duplicated data
#     EDA - Statistical analysis
#     Descriptive Analysis Univariate analysis Bivariate analysis multivariate analysis
#     Separate X and Y features .. Independent and Dependent features
#     Model building
#     Model evaluation
#     Consider the model for final predictions

# %% [markdown]
# ## Read the dataset

# %%
import pandas as pd

df = pd.read_csv(
    "https://raw.githubusercontent.com/Sindhura-tr/Datasets/refs/heads/main/50_Startups.csv"
)
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %% [markdown]
# ### There are no missing values or any duplicated data in this dataset.

# %% [markdown]
# ## Separate X and Y features
#     X : Independent feature
#     Y : Traget feature , Dependent feature : PROFIT

# %%
X = df[["ADMIN"]]
Y = df[["PROFIT"]]

# %%
X.head()
# Out:
#        ADMIN
# 0  136897.80
# 1  151377.59
# 2  101145.55
# 3  118671.85
# 4   91391.77

# %% [markdown]
# ## Model Building- Linear Model
#     sklearn libraries

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Ypredictions = B0 + B1*X
#     Profit_predictions = yintercept + slope * ADMIN
#     B1 => slope => coefficients => weights

# %%
model.coef_
# Out:
# array([[0.2887492]])

# %%
model.intercept_
# Out:
# array([76974.47130542])

# %% [markdown]
# ### Profit_predictions = 76974.47130542 + 0.2887492 * ADMIN

# %%
model.score(X, Y)
# Out:
# 0.04028714077757223

# %% [markdown]
# ### Model Evaluation
#     Metrics:
#     MEan Absolute Error
#     Mean Squared Error
#     Root Mean Squared Error
#     R2 score

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
ypreds = model.predict(X)
ypreds[0:5]
# Out:
# array([[116503.6018596 ],
#        [120684.62967237],
#        [106180.1681897 ],
#        [111240.87333494],
#        [103363.77199475]])

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
MSE = mean_squared_error(Y, ypreds)
MAE = mean_absolute_error(Y, ypreds)
r2 = r2_score(Y, ypreds)
RMSE = MSE ** (1 / 2)

# %%
print(f"Mean Squared Error : {MSE}")
print(f"Mean Absolute Error : {MAE}")
print(f"Root Mean Squared Error : {RMSE}")
print(f"R2 Score : {r2}")
# Out:
# Mean Squared Error : 1527955397.744143
# Mean Absolute Error : 30659.814789071817
# Root Mean Squared Error : 39089.07005473708
# R2 Score : 0.04028714077757223

# %% [markdown]
# ### Consider another X independent feature
#  x=> RND, Y=>PROFIT

# %%
X1 = df[["RND"]]

# %%
model2 = LinearRegression()
model2.fit(X1, Y)
# Out:
# LinearRegression()

# %%
ypreds2 = model2.predict(X1)

# %%
ypreds2[:5]
# Out:
# array([[190289.29389289],
#        [187938.71118575],
#        [180116.65707807],
#        [172369.00320589],
#        [170433.97345032]])

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
MSE2 = mean_squared_error(Y, ypreds2)
MAE2 = mean_absolute_error(Y, ypreds2)
r2_2 = r2_score(Y, ypreds2)
RMSE2 = MSE2 ** (1 / 2)

# %%
print(f"Mean Sqaured Error: {MSE2}")
print(f"Mean Absolute Error: {MAE2}")
print(f"Root Mean Sqaured Error: {RMSE2}")
print(f"R2 Score: {r2_2}")
# Out:
# Mean Sqaured Error: 85120931.32706906
# Mean Absolute Error: 6910.98435457961
# Root Mean Sqaured Error: 9226.100548285232
# R2 Score: 0.9465353160804393
